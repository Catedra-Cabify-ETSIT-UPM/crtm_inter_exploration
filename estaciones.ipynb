# %%
import pandas as pd
import requests
import os

# %%
file_path = 'm8_Estaciones.json'

if not os.path.exists(file_path):
  url = 'https://opendata.arcgis.com/datasets/19884a02ac044270b91fa478d80f7858_0.csv?outSR=%7B%22latestWkid%22%3A25830%2C%22wkid%22%3A25830%7D'
  r = requests.get(url)
  with open(file_path, 'w') as f:
    f.write(r.content.decode("utf-8"))

with open(file_path, 'r') as f:
  est = pd.read_csv(f)

# %%
est.head()
# Out:
#    OBJECTID IDESTACION  FECHAACTUAL  MODO  CODIGOESTACION  \
# 0      8001    8_20316     20190912     8           20316
# 1      8002    8_20658     20190912     8           20658
# 2      8003    8_20660     20190912     8           20660
# 3      8004    8_20152     20190912     8           20152
# 4      8005    8_20410     20190912     8           20410
#
#                                DENOMINACION OBSERVACIONES SITUACION  \
# 0                    EST.PUERTA DE BOADILLA           NaN         S
# 1              LA NORIA-POZO DE GUADALAJARA           NaN         S
# 2             MANUEL AZAÑA-CENTRO COMERCIAL           NaN         S
# 3  ALTO DE LAS CABAÑAS-CMNO.VIEJO DE MADRID           NaN         S
# 4      AV.GUSTAVO ADOLFO BÉCQUER-PÍO BAROJA           NaN         S
#
#    CODIGOCTMESTACIONREDMETRO  CODIGOEMPRESA  ... FECHAINICIO  FECHAFIN  \
# 0                        NaN            NaN  ...    20171211       NaN
# 1                        NaN            NaN  ...    20190702       NaN
# 2                        NaN            NaN  ...    20190709       NaN
# 3                        NaN            NaN  ...    20170419       NaN
# 4                        NaN            NaN  ...    20180702       NaN
#
#         X        Y  GRADOACCESIBILIDAD  SITUACIONCALLE  \
# 0  423411  4473600                   N             NaN
# 1  484603  4482777                   N             NaN
# 2  469523  4482148                   N             NaN
# 3  426818  4482613                   N             NaN
# 4  469348  4484528                   N             NaN
#
#                            DENOMINACION_SAE  INTERURBANOS_CODIGOEMT_CRTM  \
# 0                    EST.PUERTA DE BOADILLA                          NaN
# 1              LA NORIA-POZO DE GUADALAJARA                          NaN
# 2             MANUEL AZAÑA-CENTRO COMERCIAL                          NaN
# 3  ALTO DE LAS CABAÑAS-CMNO.VIEJO DE MADRID                          NaN
# 4      AV.GUSTAVO ADOLFO BÉCQUER-PÍO BAROJA                          NaN
#
#   INTERURBANOS_CODIGOEMT_EMPRESA               LINEAS
# 0                            NaN                  565
# 1                            NaN                  275
# 2                            NaN                  NaN
# 3                            NaN  621, 623, 624, N903
# 4                            NaN                  227
#
# [5 rows x 53 columns]
